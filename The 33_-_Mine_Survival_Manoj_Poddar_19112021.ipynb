# %%
"""
The_33_-_Mine_Survival
Created on 2021-10-22
Revised on 2021-11-19
@uthor - Manoj Poddar

"""
"""
    DocString:
    
    A) Introduction: This game is based on the 2015 movie 'The 33'. The movie itself is 
    based on the actual rescue of 33 Chilean miners trapped deep inside a San Jose 
    copper mine for 69 days in 2010. It can be found on 'https://www.imdb.com/title/tt2006295/'.
    The game consists of three stages, viz., 
    (i) Enter the Mine;
    (ii) Enter the Refuge; and
    (iii) Rescue Capsule. 
    
    It is a story of victory of human grit, determination and hope against the man-made and 
    natural disasters. The player has to use common sense and leadership skills to move to 
    the next stage.
        
    
    B) Known bugs and/or errors: Previous bug at line 360 removed. Checked for bugs. Not found any.

"""
####################################################
# Constructing the Game - 'The_33_-_Mine_Survival' #
#                                                  #
####################################################

from sys import exit # importing exit package for enabling exit
import time          # importing time package for enabling pause between displays
import random        # importing random package for generating random numbers

# Declaring the list of the 33 actual miners who were trapped inside the San Jose mine for 69 days 
## source - https://en.wikipedia.org/wiki/2010_Copiap%C3%B3_mining_accident
miners_list = ['Florencio', 'Mario_Sepulveda', 'Juan', 'Carlos', 'Jimmy',
                 'Osman', 'Jose', 'Claudio', 'Mario_Gomez', 'Alex', 'Jorge',
                 'Edison', 'Carlos_Barrios', 'Victor', 'Victor_Segovia', 'Daniel',
                 'Omar', 'Esteben', 'Pablo', 'Dario', 'Johny', 'Samuel',
                 'Cralos_Bugenno', 'Jose', 'Renan', 'Claudio', 'Franklin',
                 'Richard', 'Juan_Aguilar', 'Raul', 'Pedro', 'Ariel', 'Lui']

# defining start function for the game to begin
def start():
    """This function defines the start of the game"""
    # using while loop for making name input mandatory
    begin = True
    while begin:
    
    # Dclaring user name as input for the player's name
        User_name = input(prompt = """
        This game requires strong determination and team-spirit to survive. \n
        Are you ready to play? If yes, then please enter your name and press enter to
        continue.. \t""")
        
        print('')
        print('')
        # use of conditional statement for avoiding blank entry
        if len(User_name.strip())>0:
            # Using dynamic variable 
            # Using caitalize method to convert user name's first letter to capital
            print(f' Welcome to the San Jose Copper mine. Braveheart {(User_name).capitalize()}! \n\n')
            print("You join the world famous 33 miners.")
            print("")
            time.sleep(2) # using time function to delay
            begin=False
        else:
            print("name cannot be empty")
            begin=True

    
    User_name = User_name.capitalize()   #capitalizing the player's name
# Randomly adding player's name to the miners' list defined at line 38 with 'insert' method
    miners_list.insert(random.randint(1, 33), User_name)
    print("""
    You are about to enter one of the deepest mines in the world. The manager 
    takes the roll call of miners before they enter the mine. Make sure that 
    he calls your name. Raise your hand when you listen your name. \n\n\n""")
    time.sleep(3)

# using 'for' loop for calling the names from miners' list. To stop at the player's name.
    for names in miners_list:
        print(names)
        if names == User_name:
            break
    print("-"*15)     # printing lines with special characters
    print("*"*15)
    
    # Assigining position of user in the list to id_num variable
    id_num = miners_list.index(User_name) + 1 
    # converting id_num to string to avoid error in input
    id_num = str(id_num)
    print(f""" Good. He called your name at ID No.{id_num}. Remember this.\n\n""")
    a= input(prompt = "Enter your ID number\n")
    
# if statement for progressing further
    
    if a==id_num:
        print("Manager: Correct. Your memory is good.")
        print("Manager: But to enter the mine, you have to prove your knowledge of geography.")
        time.sleep(2)
        # preparing a questions list for randomly calling a question
        question_list = ['In which country is this mine located?',
                     'In which continent is this mine located?',
                     'In which city is this mine located?',
                     'In which desert is this mine located?']
        questions = 1
    # conditional while loop for random question
        while questions > 0:
            question = random.choice(question_list)
            input(prompt = "<Press enter for your question>\n")
            print(question)
            print(" ")
        # conditional statements for random question #1
            if question == question_list[0]:
                print("1) Chile.")
                print("2) Brazil.")
                print("3) Peru.")
                country = input(prompt = "Country name: \n")
                country = country.casefold()
            
                if country == '1' or country == 'chile':
                    print("Manager: You know your country.")
                    questions -=1
                    
                else:
                    print("Manager: Be better prepared next time.")
                    fail()
        
        # conditional statements for random question #2
            elif question == question_list[1]:
                print("1) South America \n")
                print("2) Europe \n")
                print("3) Africa \n")
                continent = input(prompt = "> \n")
                continent = continent.casefold()
            
                if '1' in continent or 'south' in continent or 'america' in continent:
                    print("Manager: You know your geography. \n")
                    questions -= 1
                else:
                    print("Manager: You need to refresh your geography. \n")
                    fail()
        # conditional statements for random question #3
            elif question == question_list[2]:
                print("1) New York City  \n")
                print("2) San Jose  \n")
                print("3) Santiago  \n")
        
                city = input(prompt = "> \n")
        
                if '2' in city or 'san' in city or 'jose' in city:
                    print("Manager: You know your coordinates. \n")
                    questions -= 1
            
                else:
                    print("Manager: You need to know your city. \n")
                    fail()
           # conditional statements for random question #4 
            elif question == question_list[3]:
                print("1) Atacama \n")
                print("2) Sahara \n")
                print("3) Thar \n")
            
                desert = input(prompt = "> \n")
                desert = desert.casefold()
            
                if '1' in desert or 'atacama' in desert:
                    print("Manager: You have high IQ \n")
                    questions -= 1 
            
                else:
                    print("Manager: Be better prepared next time. \n")
                    fail() 
                
                
                break
                
            
        print("You successfully answered the geography question!\n")
        print("Enter the next stage. \n")
        input(prompt = "<Press enter to continue>\n")
        stage_1()
        
        time.sleep(2)
    else:
        print("Wrong ID or input. Start again.")
        start()
       
    
    # Defining the function and the scene at the first stage of the game
    # Using time function to insert delay between scene description and question
def stage_1():
    """ 'This function defines the first stage of the game - Enter the Mine' """
    print("""
    You enter the mine with 33 other miners. The mine is 2300 ft deep inside the 
    Earth and is one of the oldest and most unsafe in the world. You all reach 
    1700 ft under the earth and start work. But suddenly the earth tremors 
    and the mine collapses. The 'Heart of the Mountain', equivalent to two Empire 
    State Buildings has collapsed, and blocked your way. You are trapped deep 
    inside the earth with no communication with outside world. \n\n""")
    time.sleep(5)
    
    
    
# the first question of stage 1
    print("""
    The first thing to do is to ensure that all miners are alive. You do a quick 
    head count. How many of you are there in total?
        1) 34
        2) 33
        3) 35 """)
    choice = input(prompt= (">  \n"))   # defining the vaiable choice
        
    # conditional loop
    if choice == '1' or choice == '34':
        print("""
        Right! Including you, there are 34 miners. Now, you have to find the 'Refuge'.
        Before that you should answer a mine survival question. \n\n""")
        # preparing a questions list for randomly calling a question
        question_list = [
        'Which bird was used for detecting poisonous gases in mines till the 20th century?',
                     'Which of the following gases is the most toxic?',
                     'Which gas is known as firedamp?']
                     
        questions = 1
    # conditional while loop for random question
        while questions > 0:
            question = random.choice(question_list)
            input(prompt = "<Press enter for your question>\n")
            print(question)
            print(" ")
        # conditional statements for random question #1
            if question == question_list[0]:
                print("1) Canary.")
                print("2) Crow.")
                print("3) Rooster.")
                bird = input(prompt = "Bird's name: \n")
                bird = bird.casefold()
            
                if bird == '1' or bird == 'canary':
                    print("You know the history of mine safety.")
                    questions -=1
                    
                else:
                    print("That is not correct. Google for correct answer and start at Stage 1 again.")
                    stage_1()
        
        # conditional statements for random question #2
            elif question == question_list[1]:
                print("1) Carbon monoxide.")
                print("2) Carbon dioxide.")
                print("3) Hydrogen.")
                toxic = input(prompt = "> \n")
                toxic = toxic.casefold()
            
                if '1' in toxic or 'mono' in toxic:
                    print("You know about toxic gases. \n")
                    questions -= 1
                else:
                    print("That is not correct. Google for correct answer and start at Stage 1 again.\n")
                    stage_1()
        # conditional statements for random question #3
            elif question == question_list[2]:
                print("1) Oxygen.")
                print("2) Methane.")
                print("3) Nitrogen.")
        
                firedamp = input(prompt = "> \n")
        
                if '2' in firedamp or 'methane' in firedamp:
                    print("You know about inflammable gases.\n")
                    questions -= 1
            
                else:
                    print("That is not correct. Google for correct answer and start at Stage 1 again.\n")
                    stage_1()
                
                break
        # creating next question for moving further after correctly answering the mine-survival question
        print("""
        After answering the mine-survival question, you all move forward.
        It is totally dark there. Your helmet lights are not wotking. How will
        you find the way to refuge?
            1) Use truck batteries.
            2) Burn fire.
            3) Walk in the dark.""")
       
        choice = input(prompt= (">  \n"))   # defining the vaiable choice for input
        choice = choice.casefold() # using casefold for converting string input into lowercase
        
        ## nested conditional loop for moving to stage 2
        if '1' in choice or 'truck' in choice or 'batteries' in choice:
            print("""That is correct. Move to stage 2.""")
            stage_2() # takes the player to stage 2
            time.sleep(3)
            
        elif '2' in choice or 'burn' in choice or 'fire' in choice:
            print("This may be dangerous in a mine. You fail to survive.")
            exit(True) # makes the player to exit the game
       
        elif '3' in choice or 'walk' in choice or 'dark' in choice:
            print("You should use all available resources to survive. Start again.  \n\n")
            stage_1() # takes the player back to the beginning of stage_1 to try again
       
        else:
            print("Invalid entry. Please try again.\n")
            input(prompt = '<Press any key to continue>\n')
            
            stage_1() # takes the player back to the beginning of stage_1 to try again
    
    # conditional loop for the stage_1 first question continues
    elif choice == '2' or choice == '33':
        print("That is not correct. Start stage 1 again")
        stage_1() #takes the player back to the beginning of stage_1 to try again
   
    elif choice == '3' or choice == '35':
        print("That is not correct. Start stage 1 again")
        stage_1() #takes the player back to the beginning of stage_1 to try again
   
    else:
        print("Invalid entry. Please try again.\n")
        time.sleep(1)
        stage_1() # takes the player back to the beginning of stage_1 to try again
    
    # Defining stage 2 and describing the scene wuth texts and print function
    # Using time function to have a pause between the description of scenes
def stage_2():
    """This function defines the second phase of the game - 'Enter the Refuge'"""
    print("""
    Refuge is a safe enclosure deep inside the mine.This particular refuge  
    could accomodate only 30 people. You find that the survival kit therein 
    contained very limited ration, which is hardly sufficient for 10 
    persons. As all the miners are hungry and exhausted, they start fighting 
    for the food. \n\n""")
    time.sleep(0.5)
    
    # The first question for stage 2
    print("""
    What a true leader would do now? 
        A) Plan a rationing system.
        B) Let them fight.
        C) Hide some food for self.  
            Input your answer in A, B, C only.""")
    
    choice = input(prompt= (">  \n"))   # defining the vaiable choice for input
    choice = choice.casefold() # using casefold for converting string input into lowercase
        
    
    # conditional loop for first question of stage 2
    if 'a' in choice or 'plan' in choice or 'rationing' in choice:
        print("""
        Right! That is the way you prepare for a long haul. 
        Now, the team has selected you as their leader. So, you have to answer
        a question on leadership.  \n\n""")
        time.sleep(0.2)
        # second question of stage 2
        # preparing a questions list for randomly calling a question
        question_list = ['Conflict is always bad for an organiztion. (True/False)',
                     'A leader should lead by example.(True/False)' ,
                     'No strategy can work when you are trapped in a mine. (True/False)']
        questions = 1
    # conditional while loop for random question
        while questions > 0:
            question = random.choice(question_list)
            input(prompt = "<Press enter for your question>\n ")
            print(question)
            print(" ")
        # conditional statements for random question #1
            if question == question_list[0]:
                conflict = input(prompt = ": \n")
                conflict = conflict.casefold()
            
                if 'f' in conflict:
                    print("Correct. Sometimes conflict creates better solutions.")
                    questions -=1
                    
                else:
                    print("Wrong. Conflict can be good in certain situations.")
                    fail()
        
        # conditional statements for random question #2
            elif question == question_list[1]:
                lead = input(prompt = "> \n ")
                lead = lead.casefold()
            
                if 't' in lead:
                    print("Yes, a true leader should always lead by example.  \n")
                    questions -= 1
                else:
                    print("Not correct. \n")
                    fail()
        # conditional statements for random question #3
            elif question == question_list[2]:
                strategy = input(prompt = "> \n ")
        
                if 'f' in strategy:
                    print("Yes, with patience and careful plan you can survive in a mine. \n")
                    questions -= 1
                else:
                    print("Not correct. \n")
                    fail()
                
                
                break
        print("""You answered the question on leadership correctly. Now, your next
        challenge is to keep your team motivated as they are likely to get disheartened.\n
        How will you keep them motivated?\n
             A) Assign tasks 
             B) Offer liquor
             C) Do nothing
             Input your answer in A, B, C only.""")
        
        choice = input(prompt= (">  \n"))   # defining the vaiable choice for input
        choice = choice.casefold() # using casefold for converting string input into lowercase
           
        # Using nested conditional loop for 2nd question of 2nd stage
        if 'a' in choice or 'assign' in choice or 'tasks' in choice :
            print("""
            Correct! This is important to keep people engaged. However, more 
            than 30 days have passed. People are losing energy and ration is 
            running out. All are getting hallucinations. But, you have the faith. 
            Then you hear the sound of drilling. That gives you a ray of hope. 
            You have kept your team motivated. That is extraordinary. Now, move 
            to stage 3.\n\n""")
        
            time.sleep(0.2) # delays the next stage by 0.2 second
            stage_3()   # takes the player to stage 3
        
        elif 'b' in choice or 'offer' in choice or 'liquor' in choice:
            print("This will dehydrate them. Start at stage 2 again")
            stage_2() # wrong answer takes the player to stage_2
            
        elif 'c' in choice or 'do' in choice or 'nothing' in choice:
            print("That is not the correct choice.")
            fail()   # makes the player to exit the game and displays fail function
            # end of nested conditional loop
            
        else:
            print("Invalid entry. Please try again.\n")
            time.sleep(1)
            stage_2() # takes the player back to the beginning of stage_1 to try again
    
    # continuing conditioal loop of the first question of the second stage
    
    elif 'b' in choice or 'let' in choice or 'fight' in choice:
        print("This way the team won't survive. Start the game again.")
        stage_1() # takes the player back to stage 1
    
    elif 'c' in choice or 'hide' in choice or 'food' in choice or 'self' in choice:
        print("That is very selfish. ")
        fail() # makes the player to exit the game and displays fail function
    
    else:
        print("Invalid entry. Please try again.\n")
        time.sleep(1)
        stage_2() # Brings the player back to the beginning of stage_2 to try again

## Defining stage 3 and scenes thereunder with text and print function. 
# Using time function for having a pause between scene description 
def stage_3():
    """This function defines the final stage of the game - 'Rescue Capsule.'"""
    # Describing the scene at stage 3
    print(""""
    You all see the blades of a drill through the roof of the Refuge and the natural
    light floods in after a long time. Your joy knows no bound. Miners regain 
    their energy and hopes for rescue. \n\n""")
   
    # First question of stage 3     
    print("""
    Now, it is important to let the rescuers immediately know that you are alive.\n 
    How will you convey that?\n
    A) Bang the drill
    B) Shout together
    C) Do nothing
    """)
    
    choice = input(prompt= (">  \n"))   # defining the vaiable choice for input
    choice = choice.casefold() # using casefold for converting string input into lowercase
    
   
    # conditional statements for moving further
    if 'a' in choice or 'bang' in choice or 'drill' in choice:
        print("Right! That way you immediately let them know that you are alive. \n")
        
        # building up subsequent rescue scene
        print("""
        Now, the rescuers have come to know that you guys are alive. 
        They make further arrangements. They drop food, medicine, water, clothes 
        and phone. You all are now able to communicate with the outside world. 
        Even the President of Chile speaks to you and assures that you would be 
        rescued at any cost. Rescuers are simultaneously working on three plans
        to drill a hole to reach the refuge where all miners are trapped. Lastly 
        one hole is successfully drilled to reach the miners and rescue them. 
        After a few days, you get the news that NASA has prepared a special 
        capsule to rescue the miners. This news has rejuvenated the team. 
        You all have become heroes. \n\n""")
        
        # second question of stage 3
        print("""
        After a few days the capsule is lowered. Only one person can get out at
        a time. As a leader, what would you do? \n""")
        
        print("""
        1) Let the weakest person go first.
        2) Try to fit more than one person in the capsule.
        3) Insist on yourself going first as your spouse is not well.\n
        Please input your answer as 1, 2 or 3 only. \n\n""")
        
        choice = input(prompt= (">  \n"))   # defining the vaiable choice for input
            
        
        # Nested conditional statement for moving further in the game
        if choice == '1':
            print("Bravo!That is the correct decision.")
            time.sleep(0.1)
            print("""
            Your team applauds your decision. You patiently guide each member to
            be rescued safely. Lastly your chance comes. You board the capsule
            and it starts lifting up. You hold your breath and say your prayers.""")
            
            # lift up of rescue capsule through countdown, use of while loop
            count = 10  # assigning 10 to count
            
            while count > 0:   # while loop
                print(count)
                count -= 1     # reduces by 1 for every keyboard press
                
                # input for countdown
                lift_up = input(prompt = "Keep pressing enter till you are out. \n")
                
            print("""
            Hey! You finally made it with your grit and determination.
            Your family and friends rush to greet you.""")
            # last question of the game
            print("""
            Before you meet them, you have to answer a last question.""") 
            
            # use of try and except to control non-integer input error
            while True:
                days = input(prompt = """
                How many days did you spend inside the mine? 
                Your options are 10, 30 and 69. \n""")
    
                try:
                    days = int(days)
                    break
        
                except:
                    print("That was not a proper input.")
                    continue
            if days == 69:
                print("You answered correctly and won the game!")
                finish()  # declares that the game has been completed successfully.
            else:
                print("That was not correct. Start at stage 3 again.")
                stage_3()
        
        # nested conditional statements for the 2nd question of 3rd stage continues
        elif choice == '2':
            print("That is a bad idea. It will tamper the capsule.")
            print("Start again at stage 3")
            stage_3() # takes the player back to stage 3
            
        elif choice == '3':
            print("That is very selfish. You don't have what it takes to be a leader.")
            fail() # declares that the player has failed
            
        else:
            print("Invalid entry. Please try again.\n")
            time.sleep(1)
            stage_3() # takes the player back to the beginning of stage_3 to try again 
    
    # conditional statements for the 1st question of the 3rd stage
    elif 'b' in choice or 'shout' in choice or 'together' in choice:
        print("Don't forget that you are deep inside the earth.")
        print("Start stage 3 again.")
        stage_3() # takes the player back to the beginning of stage_3 to try again
        
    elif 'c' in choice or 'do' in choice or 'nothing' in choice:
        print("That is a bad idea.")
        fail() # declares that the player has failed
        
    else:
        print("Invalid entry. Please try again.\n")
        input(prompt = '<Press any key to continue>\n')
        stage_3() # takes the player back to the beginning of stage_3 to try again
        
def fail(): # defining fail function to indicate that the player has failed
    print("You have failed to survive in the mine.")
    print("Thanks for playing the game.")
    exit(0)
    
def finish(): # defining finish function to indicate that the game has finished
    print("Congratulations! You won.")
    print("Thanks for playing the game.")
    

start()
# Out:
#         This game requires strong determination and team-spirit to survive.
#
#         Are you ready to play? If yes, then please enter your name and press enter to
#         continue.. 	m
#
#
#  Welcome to the San Jose Copper mine. Braveheart M!
#
#
# You join the world famous 33 miners.
#
#
#     You are about to enter one of the deepest mines in the world. The manager
#     takes the roll call of miners before they enter the mine. Make sure that
#     he calls your name. Raise your hand when you listen your name.
#
#
#
# Florencio
# Mario_Sepulveda
# Juan
# Carlos
# Jimmy
# Osman
# Jose
# Claudio
# Mario_Gomez
# Alex
# Jorge
# Edison
# Carlos_Barrios
# Victor
# Victor_Segovia
# Daniel
# Omar
# Esteben
# Pablo
# Dario
# Johny
# Samuel
# Cralos_Bugenno
# Jose
# Renan
# Claudio
# Franklin
# Richard
# Juan_Aguilar
# Raul
# Pedro
# Ariel
# Lui
# M
# ---------------
# ***************
#  Good. He called your name at ID No.34. Remember this.
#
#
# Enter your ID number
# 34
# ...
